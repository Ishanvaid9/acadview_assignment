# %%
#Graphical representation of data
import matplotlib.pyplot as plt


fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot([1, 2, 3, 4], [10, 20, 25, 30], color='lightblue', linewidth=3)
ax.scatter([0.3, 3.8, 1.2, 2.5], [11, 25, 9, 26], color='darkgreen', marker='^')
ax.set_xlim(0.5, 4.5)
plt.show()
print 'graph shown'
# Out:
# graph shown

# %%
#barplot for graph for Pclass and Survived

import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()
df=pd.read_csv('titanic.csv')
df.head()
sns.barplot(x='Pclass',y='Survived',data=df)

# %%
#barplot for graph for Sex and Survived
sns.barplot(x='Sex',y='Survived',data=df)

# %%
#voilinplot for graph for Pclass ,Age and Survived
sns.violinplot(x='Pclass',y='Age',hue='Survived' ,data=df,split=True)

# %%
#voilinplot for graph for Sex ,Age and Survived
sns.violinplot(x='Sex',y='Age',hue='Survived',data=df,split=True)

# %%
#barplot for graph for Age and Survived
sns.barplot(x='Age',y='Survived',data=df)

# %%
#voilinplot for graph for Fare and Survived
#df.plot(x='Fare',y='Survived',stacked=True, width=1,kind='barh')
sns.violinplot(x='Fare',y='Survived',data=df,split=True)

# %%
#barplot for graph for Embarked and Survived

sns.barplot(x='Embarked',y='Survived',data=df)

# %%
#voilinplot for graph for Pcalss,Sex and Survived

sns.violinplot(x='Pclass',y='Sex',hue='Survived',data=df,split=True)
